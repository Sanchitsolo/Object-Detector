# %%
import pandas as pd
filename='img1&2.csv'
df=pd.read_csv(filename, sep=' ')

# %%
lst=list(df.iloc[:,0])

# %%
ls1=[]
ls2=[]
for i in lst:
    if 'img1' in i:
        ls1.append(i)
    else:
        ls2.append(i)

# %%
len(ls1)
# Out:
# 702

# %%
df.iloc[701,:]
# Out:
# imageFilename    /home/trainee/intern/final img/img1/999.jpg
# building_1                                               NaN
# building_2                                               NaN
# building_3                                               NaN
# building_4                                               NaN
# building_5                                               NaN
# building_6                                               NaN
# building_7                                               NaN
# building_8                                               NaN
# building_9                                               NaN
# building_10                                              NaN
# building_11                                              NaN
# building_12                                              NaN
# building_13                                              NaN
# building_14                                              NaN
# ...

# %%
df1=df.iloc[:702,:]

# %%
df1
# Out:
#                                    imageFilename  building_1  building_2  \
# 0      /home/trainee/intern/final img/img1/0.jpg         NaN         NaN
# 1      /home/trainee/intern/final img/img1/1.jpg         NaN         NaN
# 2     /home/trainee/intern/final img/img1/10.jpg         NaN         NaN
# 3    /home/trainee/intern/final img/img1/103.jpg         NaN         NaN
# 4    /home/trainee/intern/final img/img1/108.jpg         NaN         NaN
# 5     /home/trainee/intern/final img/img1/11.jpg         NaN         NaN
# 6    /home/trainee/intern/final img/img1/117.jpg         NaN         NaN
# 7    /home/trainee/intern/final img/img1/118.jpg         NaN         NaN
# 8     /home/trainee/intern/final img/img1/12.jpg         NaN         NaN
# 9    /home/trainee/intern/final img/img1/128.jpg       126.0         3.0
# 10   /home/trainee/intern/final img/img1/147.jpg         NaN         NaN
# 11   /home/trainee/intern/final img/img1/148.jpg         NaN         NaN
# ...

# %%
df2=df.iloc[702:,:]

# %%
df2
# Out:
#                                     imageFilename  building_1  building_2  \
# 702     /home/trainee/intern/final img/img2/0.jpg         NaN         NaN
# 703     /home/trainee/intern/final img/img2/1.jpg       210.0         1.0
# 704    /home/trainee/intern/final img/img2/10.jpg         4.0        20.0
# 705   /home/trainee/intern/final img/img2/100.jpg         NaN         NaN
# 706   /home/trainee/intern/final img/img2/101.jpg         NaN         NaN
# 707   /home/trainee/intern/final img/img2/102.jpg         NaN         NaN
# 708   /home/trainee/intern/final img/img2/103.jpg         NaN         NaN
# 709   /home/trainee/intern/final img/img2/105.jpg         NaN         NaN
# 710   /home/trainee/intern/final img/img2/106.jpg         NaN         NaN
# 711   /home/trainee/intern/final img/img2/107.jpg         NaN         NaN
# 712   /home/trainee/intern/final img/img2/108.jpg       483.0       305.0
# 713   /home/trainee/intern/final img/img2/109.jpg         NaN         NaN
# ...

# %%
exp_df1=df1.to_csv(r'dataset/img1.csv', index=None, sep=' ', header=True)
exp_df2=df2.to_csv(r'dataset/img2.csv', index=None, sep=' ', header=True)
